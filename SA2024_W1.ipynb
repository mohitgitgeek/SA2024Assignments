# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitgitgeek/SA2024Assignments/blob/main/SA2024_W1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2024! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df = pd.read_csv('SA2024_W1_Pokemon.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
#your code here
df.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
#your code here
df.drop('#',axis=1)
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
#your code here
df.set_index('Name')
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
#your code here
list(df['Type 1'].unique())
# Out:
# ['Grass',
#  'Fire',
#  'Water',
#  'Bug',
#  'Normal',
#  'Poison',
#  'Electric',
#  'Ground',
#  'Fairy',
#  'Fighting',
#  'Psychic',
#  'Rock',
#  'Ghost',
#  'Ice',
#  'Dragon',
#  'Dark',
#  'Steel',
#  'Flying']

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
#your code here
import pandas as pd
# Assuming you have a dataframe called 'pokemon' with columns 'Type 1' and 'Type 2'
df['Combined_Types'] = df['Type 1'] + '+' + df['Type 2']
# Count the number of pokemons with 'Psychic' as type-1 and 'Flying' as type-2
print(df[df['Combined_Types'] == 'Psychic+Flying'].shape[0])
# Out:
# 6

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
#your code here
df[df['Name'].str.contains('Mega')].count()
# Out:
# #                 49
# Name              49
# Type 1            49
# Type 2            39
# Total             49
# HP                49
# Attack            49
# Defense           49
# Sp. Atk           49
# Sp. Def           49
# Speed             49
# Generation        49
# Legendary         49
# Combined_Types    39
# dtype: int64

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
#your code here
df['Sp. Def'].std()
# Out:
# 27.82891579711746

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
#your code here
df[df['Legendary']==True].count()/df.count()
# Out:
# #                 0.081250
# Name              0.081250
# Type 1            0.081250
# Type 2            0.096618
# Total             0.081250
# HP                0.081250
# Attack            0.081250
# Defense           0.081250
# Sp. Atk           0.081250
# Sp. Def           0.081250
# Speed             0.081250
# Generation        0.081250
# Legendary         0.081250
# Combined_Types    0.096618
# dtype: float64

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
#your code here
df[df['Defense']==df['Defense'].max()]
# Out:
#        #                 Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 224  208  SteelixMega Steelix  Steel  Ground    610  75     125      230
# 230  213              Shuckle    Bug    Rock    505  20      10      230
# 333  306    AggronMega Aggron  Steel     NaN    630  70     140      230
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary Combined_Types
# 224       55       95     30           2      False   Steel+Ground
# 230       10      230      5           2      False       Bug+Rock
# 333       60       80     50           3      False            NaN

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
#your code here
df[(df['Type 1']=='Poison')].sort_values('Attack',ascending=False)
# Out:
#        #       Name  Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 504  454  Toxicroak  Poison  Fighting    490   83     106       65       86
# 96    89        Muk  Poison       NaN    500  105     105       75       65
# 39    34   Nidoking  Poison    Ground    505   81     102       77       85
# 368  336    Seviper  Poison       NaN    458   73     100       60      100
# 630  569   Garbodor  Poison       NaN    474   80      95       82       60
# 483  435   Skuntank  Poison      Dark    479  103      93       67       71
# 36    31  Nidoqueen  Poison    Ground    505   90      92       87       75
# 183  169     Crobat  Poison    Flying    535   85      90       80       70
# 118  110    Weezing  Poison       NaN    490   65      90      120       85
# 502  452    Drapion  Poison      Dark    500   70      90      110       60
# 29    24      Arbok  Poison       NaN    438   60      85       69       65
# ...

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
#your code here
sns.barplot(x='#',y='Type 1',data=df)
# Out:
# <Axes: xlabel='#', ylabel='Type 1'>

# %%
#your code here
sns.boxplot(x='Attack',y='Defense',data=df)
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %%
#your code here
sns.kdeplot(x='Attack',y='Defense',data=df)
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
#your code here
df[(df['Type 1']=='Ghost') & (df['Generation']==4) & (df['Legendary']==False)].sort_values('Speed',ascending=False).iloc[1]
# Out:
# #                          426
# Name                  Drifblim
# Type 1                   Ghost
# Type 2                  Flying
# Total                      498
# HP                         150
# Attack                      80
# Defense                     44
# Sp. Atk                     90
# Sp. Def                     54
# Speed                       80
# Generation                   4
# Legendary                False
# Combined_Types    Ghost+Flying
# Name: 473, dtype: object

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
# prompt: How many non-legendary pokemons have stronger defence but weaker attack than Charizard?
# Generate the code that satisfies the question

charizard_defense = df[df['Name'] == 'Charizard']['Defense'].values[0]
charizard_attack = df[df['Name'] == 'Charizard']['Attack'].values[0]

non_legendary_df = df[df['Legendary'] == False]

stronger_defense_weaker_attack_df = non_legendary_df[(non_legendary_df['Defense'] > charizard_defense) & (non_legendary_df['Attack'] < charizard_attack)]

num_pokemon = stronger_defense_weaker_attack_df.shape[0]

print(f"There are {num_pokemon} non-legendary pokemons with stronger defense but weaker attack than Charizard.")
# Out:
# There are 116 non-legendary pokemons with stronger defense but weaker attack than Charizard.

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, here are some bonus questions that you can try to further deepen your understanding of the topic!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
#your code here

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
#your code here

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
#your code here

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
